# %%
import numpy as np
import pandas as pd
import re
import os

# %% [markdown]
# # combine all data and clean

# %%
df_moviegenre = pd.read_csv('../movie-genre-from-its-poster/MovieGenre.csv', encoding='latin1')

df_movies = pd.read_csv('../the-movies-dataset/movies_metadata.csv', encoding='latin1')
df_credits = pd.read_csv('../the-movies-dataset/credits.csv', encoding='latin1')
df_keywords = pd.read_csv('../the-movies-dataset/keywords.csv', encoding='latin1')
# Out:
# /home/grigor/anaconda3/envs/dataViz/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# take only English movies and relaesed after 1980 
df_movies = df_movies[df_movies['original_language'] == 'en']
df_movies = df_movies.astype({'original_language': str, 'release_date': np.datetime64,
                             'id': np.int64})
df_movies = df_movies[df_movies['release_date'] >= '1980-01-01']

# %%
df_credits.duplicated(['id']).sum()
# Out:
# 44

# %%
df_credits = df_credits.drop_duplicates(subset=['id'])
df_keywords = df_keywords.drop_duplicates(subset=['id'])
df_moviegenre = df_moviegenre.drop_duplicates(subset = 'imdb_id')

df_moviegenre.rename({'imdbId': 'imdb_id'}, axis='columns', inplace = True)

# %%
df = df_movies.merge(df_credits, how='inner', on='id')

# %%
df = df.merge(df_keywords, on='id')

# %%
df = df.astype({'imdb_id': str})

# %%
df['imdb_id'] = df['imdb_id'].apply(lambda s: re.sub('[a-zA-Z]+', '', s))

# %%
df = df[df['imdb_id'] != ''].astype({'imdb_id': np.int64})

# %%
df = df.merge(df_moviegenre, on='imdb_id')

# %%
df = df.drop_duplicates(subset = 'imdb_id')

# %%
df.to_csv('../movies.csv')

# %% [markdown]
# ## end combining

# %%
df[df['imdb_id'] == 114709]
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                homepage   id  imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862   114709                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
#
#   vote_average vote_count                                               cast  \
# 0          7.7     5415.0  [{'cast_id': 14, 'character': 'Woody (voice)',...
#
#                                                 crew  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
#
#                                             keywords  \
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
#
#                             Imdb Link             Title IMDB Score  \
# 0  http://www.imdb.com/title/tt114709  Toy Story (1995)        8.3
#
#                         Genre  \
# 0  Animation|Adventure|Comedy
#
#                                               Poster
# 0  https://images-na.ssl-images-amazon.com/images...
#
# [1 rows x 32 columns]

# %%
imdb_ids = os.listdir('../movie-genre-from-its-poster/SampleMoviePosters/SampleMoviePosters/')

# %%
ids = [re.sub('.[a-zA-Z]+', '', s) for s in imdb_ids]

# %%
len(ids)
# Out:
# 997

# %%
df
# Out:
#        adult                              belongs_to_collection     budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...   30000000
# 1      False                                                NaN   65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...          0
# 3      False                                                NaN   16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...          0
# ...      ...                                                ...        ...
# 20689  False                                                NaN          0
# 20690  False                                                NaN          0
# 20691  False                                                NaN          0
# 20692  False                                                NaN  125000000
# 20693  False                                                NaN          0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 20689  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 20690                     [{'id': 35, 'name': 'Comedy'}]
# 20691                                                 []
# 20692  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 20693                                                 []
#
#                                    homepage      id  imdb_id  \
# 0      http://toystory.disney.com/toy-story     862   114709
# 1                                       NaN    8844   113497
# 2                                       NaN   15602   113228
# 3                                       NaN   31357   114885
# 4                                       NaN   11862   113041
# ...                                     ...     ...      ...
# 20689                                   NaN   68482    83168
# 20690                                   NaN   55996    82875
# 20691                                   NaN   29638   815258
# 20692   http://www.hbo.com/band-of-brothers  331214   185906
# 20693                                   NaN  353921   238304
#
#       original_language                original_title  \
# 0                    en                     Toy Story
# 1                    en                       Jumanji
# 2                    en              Grumpier Old Men
# 3                    en             Waiting to Exhale
# 4                    en   Father of the Bride Part II
# ...                 ...                           ...
# 20689                en                Tanya's Island
# 20690                en                Pacific Banana
# 20691                en  Werewolf in a Women's Prison
# 20692                en              Band of Brothers
# 20693                en                  Inside Out 3
#
#                                                 overview  ... vote_average  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...          7.7
# 1      When siblings Judy and Peter discover an encha...  ...          6.9
# 2      A family wedding reignites the ancient feud be...  ...          6.5
# 3      Cheated on, mistreated and stepped on, the wom...  ...          6.1
# 4      Just when George Banks has recovered from his ...  ...          5.7
# ...                                                  ...  ...          ...
# 20689  Tanya is a female model who lives with her boy...  ...          6.0
# 20690  The story of a pair of Australian pilots worki...  ...          4.8
# 20691                                 No overview found.  ...          4.0
# 20692  Drawn from interviews with survivors of Easy C...  ...          8.2
# 20693  Playboy does to softcore sex films what HBO's ...  ...          0.0
#
#       vote_count                                               cast  \
# 0         5415.0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1         2413.0  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2           92.0  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3           34.0  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4          173.0  [{'cast_id': 1, 'character': 'George Banks', '...
# ...          ...                                                ...
# 20689        3.0  [{'cast_id': 1, 'character': 'Tanya (as D.D. W...
# 20690        3.0  [{'cast_id': 1, 'character': 'Martin', 'credit...
# 20691        5.0  [{'cast_id': 6, 'character': 'Sarah Ragdale', ...
# 20692      725.0  [{'cast_id': 1, 'character': 'Lt. Richard D. W...
# 20693        0.0  [{'cast_id': 10, 'character': 'Actor (segment ...
#
#                                                     crew  \
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 20689  [{'credit_id': '55bf72709251413e58006a78', 'de...
# 20690  [{'credit_id': '52fe48e9c3a36847f8180125', 'de...
# 20691  [{'credit_id': '52fe45efc3a368484e077595', 'de...
# 20692  [{'credit_id': '56731cd9c3a368070c002fbd', 'de...
# 20693  [{'credit_id': '55c8cff7c3a3686b5f000b3d', 'de...
#
#                                                 keywords  \
# 0      [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1      [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2      [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3      [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4      [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# ...                                                  ...
# 20689  [{'id': 966, 'name': 'beach'}, {'id': 2041, 'n...
# 20690  [{'id': 572, 'name': 'sex'}, {'id': 966, 'name...
# 20691                                                 []
# 20692  [{'id': 1956, 'name': 'world war ii'}, {'id': ...
# 20693                                                 []
#
#                                 Imdb Link                               Title  \
# 0      http://www.imdb.com/title/tt114709                    Toy Story (1995)
# 1      http://www.imdb.com/title/tt113497                      Jumanji (1995)
# 2      http://www.imdb.com/title/tt113228             Grumpier Old Men (1995)
# 3      http://www.imdb.com/title/tt114885            Waiting to Exhale (1995)
# 4      http://www.imdb.com/title/tt113041  Father of the Bride Part II (1995)
# ...                                   ...                                 ...
# 20689   http://www.imdb.com/title/tt83168               Tanya's Island (1980)
# 20690   http://www.imdb.com/title/tt82875               Pacific Banana (1981)
# 20691  http://www.imdb.com/title/tt815258  Werewolf in a Womens Prison (2006)
# 20692  http://www.imdb.com/title/tt185906                    Band of Brothers
# 20693  http://www.imdb.com/title/tt238304               Inside Out III (1992)
#
#       IMDB Score                       Genre  \
# 0            8.3  Animation|Adventure|Comedy
# 1            6.9     Action|Adventure|Family
# 2            6.6              Comedy|Romance
# 3            5.7        Comedy|Drama|Romance
# 4            5.9       Comedy|Family|Romance
# ...          ...                         ...
# 20689        4.3                       Drama
# 20690        4.7                      Comedy
# 20691        4.5                      Horror
# 20692        9.5        Action|Drama|History
# 20693        4.9        Comedy|Drama|Romance
#
#                                                   Poster
# 0      https://images-na.ssl-images-amazon.com/images...
# 1      https://images-na.ssl-images-amazon.com/images...
# 2      https://images-na.ssl-images-amazon.com/images...
# 3      https://images-na.ssl-images-amazon.com/images...
# 4      https://images-na.ssl-images-amazon.com/images...
# ...                                                  ...
# 20689  https://images-na.ssl-images-amazon.com/images...
# 20690  https://images-na.ssl-images-amazon.com/images...
# 20691  https://images-na.ssl-images-amazon.com/images...
# 20692  https://images-na.ssl-images-amazon.com/images...
# 20693  https://images-na.ssl-images-amazon.com/images...
#
# [20682 rows x 32 columns]
